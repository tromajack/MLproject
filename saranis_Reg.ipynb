# %% [markdown]
# <a href="https://colab.research.google.com/github/tromajack/MLproject/blob/main/saranis_Reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing the dataset**

# %%
recovery = pd.read_excel('sarani_analysis.xlsx')
recovery.head()
# Out:
#    POLT HRS.       DATE  PLANT LOAD/ATP  ARGON PRODUCT FLOW         HPGOX  \
# 0         24 2022-01-02   101469.481000          708.078854  18284.306784
# 1         24 2022-01-03   101842.568608          727.030720  18600.970223
# 2         24 2022-01-04   102091.448597          685.934755  18603.304888
# 3         24 2022-01-05   102320.048009          731.607068  18808.140376
# 4         24 2022-01-06   103115.694299          718.281676  19082.040854
#
#    PLANT LOAD/ATP.1    LPC MID  LPC MID TEMP.    WN2 TO EVC  WN2 TO HEATER  \
# 0     101469.481000  28.622243    -184.694864  21832.248113   37929.334109
# 1     101842.568608  28.808237    -184.684309  22161.282107   37739.232868
# 2     102091.448597  28.526715    -184.734448  21620.525248   38522.677739
# 3     102320.048009  27.877534    -184.840907  22024.770908   38154.367823
# 4     103115.694299  28.142938    -184.820627  21197.382574   40250.179486
#
# ...

# %% [markdown]
# **Analysing the data**

# %%
recovery.columns
# Out:
# Index(['POLT HRS.', 'DATE', 'PLANT LOAD/ATP', 'ARGON PRODUCT FLOW', 'HPGOX',
#        'PLANT LOAD/ATP.1', 'LPC MID', 'LPC MID TEMP.', 'WN2 TO EVC',
#        'WN2 TO HEATER', 'WN2 PURITY', 'IL FLOW', 'PL FLOW', 'LPGAN', 'HPGAN',
#        'GOX/GAN', 'TOTAL GAN', 'LPGOX VENT', 'HPC MID',
#        'TOTAL LIN GROSS PROD.', 'LPC PRESSURE', 'CALCULATED ARGON RECOVERY'],
#       dtype='object')

# %%
recovery.drop(['POLT HRS.', 'DATE','TOTAL LIN GROSS PROD.'],axis = 1, inplace = True)
recovery.head()
# Out:
#    PLANT LOAD/ATP  ARGON PRODUCT FLOW         HPGOX  PLANT LOAD/ATP.1  \
# 0   101469.481000          708.078854  18284.306784     101469.481000
# 1   101842.568608          727.030720  18600.970223     101842.568608
# 2   102091.448597          685.934755  18603.304888     102091.448597
# 3   102320.048009          731.607068  18808.140376     102320.048009
# 4   103115.694299          718.281676  19082.040854     103115.694299
#
#      LPC MID  LPC MID TEMP.    WN2 TO EVC  WN2 TO HEATER  WN2 PURITY  \
# 0  28.622243    -184.694864  21832.248113   37929.334109    0.707951
# 1  28.808237    -184.684309  22161.282107   37739.232868    0.703647
# 2  28.526715    -184.734448  21620.525248   38522.677739    0.782947
# 3  27.877534    -184.840907  22024.770908   38154.367823    0.757256
# 4  28.142938    -184.820627  21197.382574   40250.179486    0.626956
#
#         IL FLOW       PL FLOW        LPGAN         HPGAN   GOX/GAN  \
# ...

# %% [markdown]
# **Check for missing data**

# %%
recovery.isnull().sum()
# Out:
# PLANT LOAD/ATP               0
# ARGON PRODUCT FLOW           0
# HPGOX                        0
# PLANT LOAD/ATP.1             0
# LPC MID                      0
# LPC MID TEMP.                0
# WN2 TO EVC                   0
# WN2 TO HEATER                0
# WN2 PURITY                   0
# IL FLOW                      0
# PL FLOW                      0
# LPGAN                        0
# HPGAN                        0
# GOX/GAN                      0
# TOTAL GAN                    0
# LPGOX VENT                   0
# HPC MID                      0
# LPC PRESSURE                 0
# CALCULATED ARGON RECOVERY    0
# dtype: int64

# %% [markdown]
# **Separating x and y **

# %%
x = recovery.iloc[:,:-1].values
y = recovery.iloc[:,-1].values

# %%
print(y)
# Out:
# [0.74713539 0.76432232 0.71936046 0.76554422 0.74580131 0.76747424
#  0.7808476  0.77800467 0.7634918  0.76566945 0.78021303 0.77853135
#  0.76781133 0.75541142 0.68669344 0.67686363 0.67872675 0.59127096
#  0.49264062 0.54063574 0.65821611 0.52501594 0.64557258 0.68401994
#  0.7160759  0.76874576 0.65115175 0.49353053 0.51111635 0.51659178
#  0.51664891 0.51438363 0.5302258  0.62798805 0.64430515 0.56818346
#  0.62692805 0.6336532  0.65678694 0.75187132 0.71905217 0.74709122
#  0.74123538 0.74678541 0.75355389 0.77531339 0.74132536 0.79160237
#  0.74207031 0.75103507 0.7498496  0.72886703 0.75551238 0.73504176
#  0.74910065 0.73797469 0.06853992 0.70991181 0.79053822 0.79653957
#  0.74191204 0.74167481 0.75518979 0.76260351 0.78291475 0.76201589
#  0.73973791 0.69620111 0.72716973 0.71856366 0.72360546 0.72302329
#  0.72265985 0.77841619 0.70564148 0.70792689 0.7336967  0.73425325
#  0.74031955 0.72649482 0.72526928 0.72717519 0.74869183 0.7522243
# ...

# %% [markdown]
# **Correlation matrix**

# %%
import seaborn as sns
recovery.corr()
# Out:
#                            PLANT LOAD/ATP  ARGON PRODUCT FLOW     HPGOX  \
# PLANT LOAD/ATP                   1.000000            0.537325  0.911662
# ARGON PRODUCT FLOW               0.537325            1.000000  0.525224
# HPGOX                            0.911662            0.525224  1.000000
# PLANT LOAD/ATP.1                 1.000000            0.537325  0.911662
# LPC MID                         -0.509579           -0.517067 -0.609858
# LPC MID TEMP.                   -0.212767           -0.416287 -0.348587
# WN2 TO EVC                      -0.224269            0.015652 -0.228343
# WN2 TO HEATER                    0.941119            0.537050  0.860698
# WN2 PURITY                       0.031467           -0.554198 -0.013720
# IL FLOW                          0.873701            0.518302  0.746432
# PL FLOW                          0.683774            0.648802  0.625746
# LPGAN                            0.468252           -0.116229  0.465496
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
print(x)
# Out:
# [[-0.79048734 -0.07191005 -0.2918699  ...  0.92177289 -1.06892509
#   -1.50577557]
#  [-0.75028136  0.12292937 -0.10983069 ...  0.79726359 -1.50856872
#   -1.47277323]
#  [-0.72346068 -0.29956803 -0.10848857 ...  0.8416028  -1.56058503
#   -1.47587532]
#  ...
#  [ 1.16756176  1.30257032  0.35746894 ...  0.04652466  0.04521463
#    0.1861578 ]
#  [ 0.2635141   0.43510316 -0.7644706  ...  0.38346956 -0.1875336
#   -0.43000448]
#  [-0.39877815  0.33744743 -1.30646456 ...  1.66416609 -0.70585522
#   -0.6593626 ]]

# %% [markdown]
# **Splitting the dataset into training and test data**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=0)

# %% [markdown]
# **Fitting the model on training data**

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Predicting test set results**

# %%
y_pred = lin_reg.predict(x_test)

# %% [markdown]
# **Checking accuracy**

# %%
from sklearn.metrics import r2_score
r2_score(y_pred, y_test)
# Out:
# 0.9918763268231143
